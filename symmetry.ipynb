# %%
from pymatgen.ext.matproj import MPRester
from IPython.display import Image
from pymatgen.core.operations import SymmOp
from pprint import pprint
with MPRester("P2FTs1l6Xaon8AOI") as m: 
    structure = m.get_structure_by_material_id("mp-28240")

# %%
pprint("Element de symétrie -x+y, -x, z")
pprint("Coordonées initiales de l'atome C: [0.0,  0.0,  0.8]")
S1 = SymmOp.from_xyz_string("-x+y, -x, z")
pprint("Matrice de rotation")
pprint(S1.rotation_matrix)
pprint("Vecteur de translation")
pprint(S1.translation_vector)
pprint("Coordonées finales : ")
pprint(S1.operate([0.0,  0.0,  0.8]))

Image(filename='-x+y, -x, z.png')
# Out:
# 'Element de symétrie -x+y, -x, z'
# "Coordonées initiales de l'atome C: [0.0,  0.0,  0.8]"
# 'Matrice de rotation'
# array([[-1.,  1.,  0.],
#        [-1.,  0.,  0.],
#        [ 0.,  0.,  1.]])
# 'Vecteur de translation'
# array([0., 0., 0.])
# 'Coordonées finales : '
# array([0. , 0. , 0.8])

# %%
pprint("Element de symétrie -y, -x, z")
pprint("Coordonées initiales de l'atome S: [0.0,  0.0,  0.54]")
S2 = SymmOp.from_xyz_string("-y, -x, z")
pprint("Matrice de rotation")
pprint(S2.rotation_matrix)
pprint("Vecteur de translation")
pprint(S2.translation_vector)
pprint("Coordonées finales : ")
pprint(S2.operate([0.0,  0.0,  0.54]))


Image(filename='-y, -x, z.png')
# Out:
# 'Element de symétrie -y, -x, z'
# "Coordonées initiales de l'atome S: [0.0,  0.0,  0.54]"
# 'Matrice de rotation'
# array([[ 0., -1.,  0.],
#        [-1.,  0.,  0.],
#        [ 0.,  0.,  1.]])
# 'Vecteur de translation'
# array([0., 0., 0.])
# 'Coordonées finales : '
# array([0.  , 0.  , 0.54])

# %%
pprint("Element de symétrie x+1/3, x-y-1/3, z-1/3")
S3 = SymmOp.from_xyz_string("x+1/3, x-y-1/3, z-1/3")
pprint("Coordonées initiales de l'atome O: [0.0,  0.0,  0.99]")
pprint("Matrice de rotation")
pprint(S3.rotation_matrix)
pprint("Vecteur de translation")
pprint(S3.translation_vector)
pprint("Coordonées finales : ")
pprint(S3.operate([0.0,  0.0,  0.99]))

Image(filename='x+13, x-y-13, z-13.png')
# Out:
# 'Element de symétrie x+1/3, x-y-1/3, z-1/3'
# "Coordonées initiales de l'atome O: [0.0,  0.0,  0.99]"
# 'Matrice de rotation'
# array([[ 1.,  0.,  0.],
#        [ 1., -1.,  0.],
#        [ 0.,  0.,  1.]])
# 'Vecteur de translation'
# array([ 0.33333333, -0.33333333, -0.33333333])
# 'Coordonées finales : '
# array([ 0.33333333, -0.33333333,  0.65666667])
